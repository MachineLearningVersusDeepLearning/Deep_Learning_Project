# %% [markdown]
# ### 01. How to define Library?

# %% [markdown]
# #### 01.01 How to define os, datetime, numpy,matplotlib and tensorflow ?

# %%
import os
from datetime import datetime

import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf

# %% [markdown]
# #### 01.02. How to define tensorboard and matplotlib using magic command?

# %%
# %matplotlib inline
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# ### 02. How to load MNIST dataset?

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# ### 03. How to normalize?

# %%
x_train = x_train/np.float(np.max(x_train))
x_test = x_test/np.float(np.max(x_test))

# %%
type(x_train)
# Out:
# numpy.ndarray

# %% [markdown]
# ### 04. How to reshape from 3 dimension to 4 dimension?(number,x,y,rgb)

# %%
x_train = x_train[...,tf.newaxis]
x_test = x_test[...,tf.newaxis]

# %%
print(x_train.shape , x_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %% [markdown]
# ### 05. How to define model?

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# #### 05.01. CNN for Feature Extraction

# %%
model.add(tf.keras.layers.Conv2D(filters=16,kernel_size=(3,3),padding='SAME',input_shape=(28,28,1),activation='relu'))

# %% [markdown]
# #### 05.02. Max Pooling

# %%
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2),padding='SAME'))

# %% [markdown]
# #### 05.03. Dropout

# %%
model.add(tf.keras.layers.Dropout(0.5))

# %% [markdown]
# #### 05.04. Flatten()

# %%
model.add(tf.keras.layers.Flatten())

# %% [markdown]
# #### [05.05 Multi Layer Perceptron Used Xavier normal initial](https://keras.io/api/layers/initializers/#glorotnormal-class)

# %%
model.add(tf.keras.layers.Dense(units=10,kernel_initializer= tf.keras.initializers.GlorotNormal(),activation='softmax'))

# %% [markdown]
# ### 06. How to define adam for optimizer?

# %%
adam = tf.keras.optimizers.Adam(0.01)

# %% [markdown]
# ### 07. How to compile(not one-hot encoding) ?

# %%
model.compile(optimizer=adam,loss='sparse_categorical_crossentropy',metrics=['acc'])

# %% [markdown]
# ### 08. How to visualize summary?

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                31370
# =================================================================
# Total params: 31,530
# Trainable params: 31,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### [09. How to make tensorborad](https://www.tensorflow.org/tensorboard/tensorboard_in_notebooks?)

# %% [markdown]
# #### 09.01 How to make log  path and directory?

# %%
logdir = os.path.join('logs',datetime.now().strftime('%Y%m%d%H%M%S'))

# %% [markdown]
# #### 09.02 How to set tensorboard parameter?

# %%
tensorboard = tf.keras.callbacks.TensorBoard(
    log_dir=logdir,
    write_graph = True,
    write_images = True,
    histogram_freq = 1
)

# %% [markdown]
# #### 09.03 How to play tensorboard use magic command?

# %%
# %tensorboard --logdir logs --port 7777
# Out:
# Reusing TensorBoard on port 7777 (pid 6554), started 0:09:52 ago. (Use '!kill 6554' to kill it.)
#       <iframe id="tensorboard-frame-5c3b1371fcd24547" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5c3b1371fcd24547");
#           const url = new URL("/", window.location);
#           url.port = 7777;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### 09. How to make learning rate scheduler?

# %% [markdown]
# #### 09.01 Make a scheduler function

# %%
def schedule(epoch):
    return 0.01/(epoch+1)

# %% [markdown]
# #### 09.02 How to use Learning Rate Scheduler? (to view the learning rate, verbose=1)

# %%
learning_rate_scheduler = tf.keras.callbacks.LearningRateScheduler(schedule,verbose=1)

# %% [markdown]
# ### 10. How to do fitting using LearningRate?

# %%
history = model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=32,epochs=3,callbacks=[tensorboard,learning_rate_scheduler])
# Out:
# Train on 60000 samples, validate on 10000 samples
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 1/3
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.1212 - acc: 0.9641 - val_loss: 0.0586 - val_acc: 0.9817
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.005.
# Epoch 2/3
# 60000/60000 [==============================] - 7s 124us/sample - loss: 0.0890 - acc: 0.9728 - val_loss: 0.0541 - val_acc: 0.9841
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0033333333333333335.
# Epoch 3/3
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.0780 - acc: 0.9760 - val_loss: 0.0493 - val_acc: 0.9859

# %%
model.predict(x_test)[0]
# Out:
# array([1.1329632e-13, 4.3053007e-13, 6.7266361e-09, 3.1410488e-07,
#        1.2253011e-13, 1.2811694e-12, 2.1198796e-19, 9.9999952e-01,
#        1.0326635e-09, 1.3457571e-07], dtype=float32)

# %% [markdown]
# ### 10. How to draw loss graph?

# %%
plt.plot(history.history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()

# %% [markdown]
# ### 11. How to draw accuracy graph?

# %%
plt.plot(history.history['acc'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()

# %% [markdown]
# ### 12.How to evaluate ?

# %%
model.evaluate(x_test,y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.04929308197477367, 0.9859]
