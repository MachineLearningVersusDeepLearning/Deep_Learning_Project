# %% [markdown]
# # Library Load

# %%
import os

# %%
# %ls -al
# Out:
# total 116
# drwxrwxr-x  4 nvidia nvidia  4096 12월  7 15:29 ./
# drwxrwxr-x  3 nvidia nvidia  4096 12월  6 19:35 ../
# -rw-rw-r--  1 nvidia nvidia 13526 12월  7 00:57 01.Crawling_Selenium.ipynb
# -rw-rw-r--  1 nvidia nvidia  3176 12월  7 00:47 02_Check_the_folder_name.ipynb
# -rw-rw-r--  1 nvidia nvidia 68193 12월  7 13:09 03_Crawrling_all.ipynb
# -rw-rw-r--  1 nvidia nvidia  6175 12월  7 15:23 04_Delete All jpg Files.ipynb
# drwxrwxr-x  2 nvidia nvidia  4096 12월  7 15:29 .ipynb_checkpoints/
# drwxrwxr-x 18 nvidia nvidia  4096 12월  6 19:55 mbti/
# -rw-rw-r--  1 nvidia nvidia   127 12월  5 22:55 readme.md

# %%
real_path = os.path.realpath(".")
real_path
# Out:
# '/home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling'

# %%
import os
path = real_path + "/mbti"
folder_names = []
name_path =[]

# %%
####################################### find the character folder ##########################
for folder in os.listdir("./mbti"):
    ################################## make full path ###########################
    character_path = path+"/"+str(folder)
    ##################################  find the sex folders #####################
    sexs = os.listdir(character_path)
    for sex in sexs:
        sex_path = character_path +"/" + str(sex)
        ############################ find the persone name foldders #############3
        names = os.listdir(sex_path)
        for name in names:
            name_path = sex_path +"/" + str(name)
            print(name)
            print(name_path)
            ###################### make linux command ##################
            final_path = "rm -r "+name_path+"/"+"*.jpg"
            print(final_path)
            ######################## split sentence ####################
            print(len(name.split(' ')))
            ########################if folder name have space, then add "\" ##############
            if (len(name.split(' '))) == 2:
                ##################### in order to expree \, use "''"
                name_path = sex_path +"/" + str(name.split(' ')[0]) + str("'\'")  + str(name.split(' ')[1])
# Out:
# 에이핑크 손나은
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/에이핑크 손나은
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/에이핑크 손나은/*.jpg
# 2
# 구혜선
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/구혜선
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/구혜선/*.jpg
# 1
# 김유정
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/김유정
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/김유정/*.jpg
# 1
# 있지 류진
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/있지 류진
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/있지 류진/*.jpg
# 2
# 공민지
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/공민지
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/woman/공민지/*.jpg
# 1
# 강동원
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/man/강동원
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/man/강동원/*.jpg
# 1
# 빅뱅 지드래곤
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/man/빅뱅 지드래곤
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/man/빅뱅 지드래곤/*.jpg
# 2
# 이수혁
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/man/이수혁
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intj/man/이수혁/*.jpg
# 1
# 걸스데이 유라
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/woman/걸스데이 유라
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/woman/걸스데이 유라/*.jpg
# 2
# 여자친구 예린
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/woman/여자친구 예린
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/woman/여자친구 예린/*.jpg
# 2
# 엑소 찬열
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/엑소 찬열
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/엑소 찬열/*.jpg
# 2
# got7 잭슨
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/got7 잭슨
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/got7 잭슨/*.jpg
# 2
# 강다니엘
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/강다니엘
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/강다니엘/*.jpg
# 1
# 방탄소년단 지민
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/방탄소년단 지민
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/방탄소년단 지민/*.jpg
# 2
# 윤시윤
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/윤시윤
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/윤시윤/*.jpg
# 1
# 엑소 수호
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/엑소 수호
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfj/man/엑소 수호/*.jpg
# 2
# 소녀시대 태연
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lsfj/woman/소녀시대 태연
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/woman/마마무 화사/*.jpg
# 2
# 방탄소년단 RM
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/man/방탄소년단 RM
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/man/방탄소년단 RM/*.jpg
# 2
# 박준영
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/man/박준영
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/man/박준영/*.jpg
# 1
# 방탄소년ㄷ간 뷔
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/man/방탄소년ㄷ간 뷔
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/man/방탄소년ㄷ간 뷔/*.jpg
# 2
# 세븐틴 버논
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/man/세븐틴 버논
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/enfp/man/세븐틴 버논/*.jpg
# 2
# 우주소녀 연정
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/woman/우주소녀 연정
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/woman/우주소녀 연정/*.jpg
# 2
# 티아라 큐리
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/woman/티아라 큐리
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/woman/티아라 큐리/*.jpg
# 2
# 드림노트 유아이
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/woman/드림노트 유아이
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/woman/드림노트 유아이/*.jpg
# 2
# TXT 태현
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/TXT 태현
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/TXT 태현/*.jpg
# 2
# NCT 재현
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/NCT 재현
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/NCT 재현/*.jpg
# 2
# 비투비 정일훈
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/비투비 정일훈
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/비투비 정일훈/*.jpg
# 2
# 미스터 T 황윤성
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/미스터 T 황윤성
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/미스터 T 황윤성/*.jpg
# 3
# 잔나비 김도형
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/잔나비 김도형
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entp/man/잔나비 김도형/*.jpg
# 2
# (여자)아이들 소연
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/woman/(여자)아이들 소연
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/woman/(여자)아이들 소연/*.jpg
# 2
# 에이핑크 정은지
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/woman/에이핑크 정은지
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/woman/에이핑크 정은지/*.jpg
# 2
# 오상진
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/오상진
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/오상진/*.jpg
# 1
# 타일러
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/타일러
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/타일러/*.jpg
# 1
# 방탄소년단 진
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/방탄소년단 진
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/방탄소년단 진/*.jpg
# 2
# 방탄소년단 슈가
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/방탄소년단 슈가
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/방탄소년단 슈가/*.jpg
# 2
# 엑소 세훈
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/엑소 세훈
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/엑소 세훈/*.jpg
# 2
# 기안84
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/기안84
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/intp/man/기안84/*.jpg
# 1
# 소녀시대 써니
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/woman/소녀시대 써니
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/woman/소녀시대 써니/*.jpg
# 2
# 홍진경
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/woman/홍진경
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/woman/홍진경/*.jpg
# 1
# 차태현
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/차태현
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/차태현/*.jpg
# 1
# 빅스 혁
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/빅스 혁
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/빅스 혁/*.jpg
# 2
# 인피니트 성규
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/인피니트 성규
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/인피니트 성규/*.jpg
# 2
# iKON 정찬우
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/iKON 정찬우
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/iKON 정찬우/*.jpg
# 2
# GOT7 마크
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/GOT7 마크
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/GOT7 마크/*.jpg
# 2
# 업텐션 선율
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/업텐션 선율
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/lstj/man/업텐션 선율/*.jpg
# 2
# 러블리즈 베이비소울
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/woman/러블리즈 베이비소울
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/woman/러블리즈 베이비소울/*.jpg
# 2
# 더보이즈 주학년
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/woman/더보이즈 주학년
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/woman/더보이즈 주학년/*.jpg
# 2
# 소녀시대 티파니
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/woman/소녀시대 티파니
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/woman/소녀시대 티파니/*.jpg
# 2
# 블락비 지코
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/블락비 지코
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/블락비 지코/*.jpg
# 2
# 스윙스
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/스윙스
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/스윙스/*.jpg
# 1
# 샤이니 키
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/샤이니 키
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/샤이니 키/*.jpg
# 2
# 에이스 김병관
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/에이스 김병관
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/에이스 김병관/*.jpg
# 2
# 슈퍼주니어 이특
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/슈퍼주니어 이특
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/entj/man/슈퍼주니어 이특/*.jpg
# 2
# 트와이스 나연
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/woman/트와이스 나연
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/woman/트와이스 나연/*.jpg
# 2
# 여자친구 은하
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/woman/여자친구 은하
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/woman/여자친구 은하/*.jpg
# 2
# 유빈
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/woman/유빈
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/woman/유빈/*.jpg
# 1
# 김연아
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/woman/김연아
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/woman/김연아/*.jpg
# 1
# 장성규
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/man/장성규
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/man/장성규/*.jpg
# 1
# 박명수
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/man/박명수
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/man/박명수/*.jpg
# 1
# 펜타곤 진호
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/man/펜타곤 진호
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/man/펜타곤 진호/*.jpg
# 2
# 김종민
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/man/김종민
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/istp/man/김종민/*.jpg
# 1
# 모모랜드 주이
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/woman/모모랜드 주이
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/woman/모모랜드 주이/*.jpg
# 2
# 카드 전소민
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/woman/카드 전소민
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/woman/카드 전소민/*.jpg
# 2
# 소녀시대 수영
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/woman/소녀시대 수영
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/woman/소녀시대 수영/*.jpg
# 2
# sf9 로운
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/sf9 로운
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/sf9 로운/*.jpg
# 2
# 2PM 우영
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/2PM 우영
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/2PM 우영/*.jpg
# 2
# 하성운
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/하성운
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/하성운/*.jpg
# 1
# 비
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/비
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/비/*.jpg
# 1
# CIX 배진영
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/CIX 배진영
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/esfp/man/CIX 배진영/*.jpg
# 2
# 한채영
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/woman/한채영
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/woman/한채영/*.jpg
# 1
# 모모랜드 제인
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/woman/모모랜드 제인
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/woman/모모랜드 제인/*.jpg
# 2
# 이지혜
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/woman/이지혜
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/woman/이지혜/*.jpg
# 1
# GOT7 뱀뱀
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/GOT7 뱀뱀
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/GOT7 뱀뱀/*.jpg
# 2
# AB6IX 박우진
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/AB6IX 박우진
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/AB6IX 박우진/*.jpg
# 2
# 김민규
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/김민규
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/김민규/*.jpg
# 1
# 데프콘
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/데프콘
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/데프콘/*.jpg
# 1
# jyj 김준수
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/jyj 김준수
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/estj/man/jyj 김준수/*.jpg
# 2
# 소녀시대 태연
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/소녀시대 태연
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/소녀시대 태연/*.jpg
# 2
# 김새론
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/김새론
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/김새론/*.jpg
# 1
# 강유미
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/강유미
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/강유미/*.jpg
# 1
# 마마무 솔라
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/마마무 솔라
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/마마무 솔라/*.jpg
# 2
# 걸스데이 소진
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/걸스데이 소진
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/걸스데이 소진/*.jpg
# 2
# 김이나
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/김이나
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/woman/김이나/*.jpg
# 1
# 위너 강승윤
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/man/위너 강승윤
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/man/위너 강승윤/*.jpg
# 2
# 엑소 카이
# /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/man/엑소 카이
# rm -r /home/nvidia/Deep_Learning_Project/05.Jocoding_project_Youtube/01_Object_detection_projecs/01_crawling/mbti/infj/man/엑소 카이/*.jpg
# 2

# %%
고객파괴 destrucion x, 혁신,
