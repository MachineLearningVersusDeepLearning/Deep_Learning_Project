# %% [markdown]
# # Library Load

# %%
#!/usr/bin/python3
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import urllib.request

# %% [markdown]
# # Open the Google webpage

# %%
binary_location = "/usr/bin/google-chrome"
driver_location = "/usr/local/bin/chromedriver"


option = webdriver.ChromeOptions()
option.binary_location = binary_location

driver = webdriver.Chrome(executable_path = driver_location,chrome_options=option)
driver.get("http://www.google.co.kr")
# Out:
# <ipython-input-2-2fe359b01f4d>:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path = driver_location,chrome_options=option)

# %% [markdown]
# # Search the word

# %%
import os
real_path = os.path.realpath("/home/nvidia/ai_data/")
path = real_path + "/entertainer_picture"


####################################### find the character folder ##########################
for folder in os.listdir(path):
    ################################## make full path ###########################
    character_path = path+"/"+str(folder)
    ##################################  find the sex folders #####################
    sexs = os.listdir(character_path)
    for sex in sexs:
        sex_path = character_path +"/" + str(sex)
        ############################ find the persone name foldders #############3
        names = os.listdir(sex_path)
        for name in names:
            name_path = sex_path +"/" + str(name)
            print(name)
            print(name_path)
            ####################### open the chrome ##############################
            option = webdriver.ChromeOptions()
            option.binary_location = binary_location

            driver = webdriver.Chrome(executable_path = driver_location,chrome_options=option)
            driver.get("http://www.google.co.kr")
            
            ############################## find the search menu ################################
            elem = driver.find_element_by_name("q")
            ############################## find the word ##################################
            elem.send_keys(name)
            ################################ enter ################################
            elem.send_keys(Keys.RETURN)
            ################################  click the image ################################
            driver.find_element_by_class_name('hide-focus-ring').click()

                ############################## click the picture ##########
            images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
            for i,image in enumerate(images):
                    try:
                        image.click()
                        time.sleep(2)
                        ############################### src #############################
                        url = driver.find_element_by_xpath('/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div[1]/div[1]/div/div[2]/a/img').get_attribute("src") #  css_selector(".n3VNCb").get_attribute("src")
                        ############################ download #########################
                        r = urllib.request.urlretrieve(url,name_path+"/"+str(i)+".jpg")
                    except:
                        print("error")
                        
            driver.close()
# Out:
# 에이핑크 손나은
# /home/nvidia/ai_data/entertainer_picture/intj/woman/에이핑크 손나은
# <ipython-input-3-21dbc80c0fb2>:24: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path = driver_location,chrome_options=option)
# error
# error
# 구혜선
# /home/nvidia/ai_data/entertainer_picture/intj/woman/구혜선
# error
# error
# error
# 김유정
# /home/nvidia/ai_data/entertainer_picture/intj/woman/김유정
# error
# 있지 류진
# /home/nvidia/ai_data/entertainer_picture/intj/woman/있지 류진
# 공민지
# /home/nvidia/ai_data/entertainer_picture/intj/woman/공민지
# 강동원
# /home/nvidia/ai_data/entertainer_picture/intj/man/강동원
# error
# error
# 빅뱅 지드래곤
# /home/nvidia/ai_data/entertainer_picture/intj/man/빅뱅 지드래곤
# error
# error
# 이수혁
# /home/nvidia/ai_data/entertainer_picture/intj/man/이수혁
# error
# error
# 걸스데이 유라
# /home/nvidia/ai_data/entertainer_picture/enfj/woman/걸스데이 유라
# error
# error
# error
# 여자친구 예린
# /home/nvidia/ai_data/entertainer_picture/enfj/woman/여자친구 예린
# error
# 엑소 찬열
# /home/nvidia/ai_data/entertainer_picture/enfj/man/엑소 찬열
# error
# got7 잭슨
# /home/nvidia/ai_data/entertainer_picture/enfj/man/got7 잭슨
# error
# error
# 강다니엘
# /home/nvidia/ai_data/entertainer_picture/enfj/man/강다니엘
# 방탄소년단 지민
# /home/nvidia/ai_data/entertainer_picture/enfj/man/방탄소년단 지민
# error
# error
# error
# error
# 윤시윤
# /home/nvidia/ai_data/entertainer_picture/enfj/man/윤시윤
# error
# error
# error
# error
# 엑소 수호
# /home/nvidia/ai_data/entertainer_picture/enfj/man/엑소 수호
# error
# 소녀시대 태연
# /home/nvidia/ai_data/entertainer_picture/lsfj/woman/소녀시대 태연
# error
# error
# error
# error
# error
# 트와이스 정연
# /home/nvidia/ai_data/entertainer_picture/lsfj/woman/트와이스 정연
# error
# error
# error
# error
# 브라운 아이드걸스 나르샤
# /home/nvidia/ai_data/entertainer_picture/lsfj/woman/브라운 아이드걸스 나르샤
# 안영미
# /home/nvidia/ai_data/entertainer_picture/lsfj/woman/안영미
# error
# error
# error
# error
# 트와이스 다현
# /home/nvidia/ai_data/entertainer_picture/lsfj/woman/트와이스 다현
# error
# 여자친구 신비
# /home/nvidia/ai_data/entertainer_picture/lsfj/woman/여자친구 신비
# error
# error
# error
# 몬스타엑스 셔누
# /home/nvidia/ai_data/entertainer_picture/lsfj/man/몬스타엑스 셔누
# 동방신기 최강창민
# /home/nvidia/ai_data/entertainer_picture/lsfj/man/동방신기 최강창민
# 걸스데이 혜리
# /home/nvidia/ai_data/entertainer_picture/esfj/woman/걸스데이 혜리
# error
# error
# error
# 에이핑크 김남주
# /home/nvidia/ai_data/entertainer_picture/esfj/woman/에이핑크 김남주
# 오마이걸 효정
# /home/nvidia/ai_data/entertainer_picture/esfj/woman/오마이걸 효정
# error
# error
# 뉴이스트 민현
# /home/nvidia/ai_data/entertainer_picture/esfj/man/뉴이스트 민현
# error
# error
# 신화 앤디
# /home/nvidia/ai_data/entertainer_picture/esfj/man/신화 앤디
# 스트레이키즈 승민
# /home/nvidia/ai_data/entertainer_picture/esfj/man/스트레이키즈 승민
# error
# error
# 방탄소년단 제이홉
# /home/nvidia/ai_data/entertainer_picture/esfj/man/방탄소년단 제이홉
# error
# error
# error
# error
# 슈퍼주니어 규현
# /home/nvidia/ai_data/entertainer_picture/esfj/man/슈퍼주니어 규현
# error
# 선미
# /home/nvidia/ai_data/entertainer_picture/infp/woman/선미
# 백예린
# /home/nvidia/ai_data/entertainer_picture/infp/woman/백예린
# error
# error
# error
# 김숙
# /home/nvidia/ai_data/entertainer_picture/infp/woman/김숙
# error
# error
# 레드벨벳 조이
# /home/nvidia/ai_data/entertainer_picture/infp/woman/레드벨벳 조이
# error
# error
# error
# 아이유
# /home/nvidia/ai_data/entertainer_picture/infp/woman/아이유
# 에픽하이 타블로
# /home/nvidia/ai_data/entertainer_picture/infp/man/에픽하이 타블로
# error
# error
# 강호동
# /home/nvidia/ai_data/entertainer_picture/infp/man/강호동
# error
# 진세연
# /home/nvidia/ai_data/entertainer_picture/isfp/woman/진세연
# 레드벨벳 슬기
# /home/nvidia/ai_data/entertainer_picture/isfp/woman/레드벨벳 슬기
# error
# Exid LE
# /home/nvidia/ai_data/entertainer_picture/isfp/woman/Exid LE
# error
# error
# 엑소 백현
# /home/nvidia/ai_data/entertainer_picture/isfp/man/엑소 백현
# error
# 은지원
# /home/nvidia/ai_data/entertainer_picture/isfp/man/은지원
# error
# error
# error
# 유재석
# /home/nvidia/ai_data/entertainer_picture/isfp/man/유재석
# 김영철
# /home/nvidia/ai_data/entertainer_picture/isfp/man/김영철
# error
# 권정열
# /home/nvidia/ai_data/entertainer_picture/isfp/man/권정열
# error
# error
# 홍진영
# /home/nvidia/ai_data/entertainer_picture/enfp/woman/홍진영
# error
# error
# 이효리
# /home/nvidia/ai_data/entertainer_picture/enfp/woman/이효리
# error
# error
# error
# error
# 전소미
# /home/nvidia/ai_data/entertainer_picture/enfp/woman/전소미
# error
# error
# 마마무 화사
# /home/nvidia/ai_data/entertainer_picture/enfp/woman/마마무 화사
# error
# error
# 방탄소년단 RM
# /home/nvidia/ai_data/entertainer_picture/enfp/man/방탄소년단 RM
# 방탄소년단 뷔
# /home/nvidia/ai_data/entertainer_picture/enfp/man/방탄소년단 뷔
# error
# error
# 박준영
# /home/nvidia/ai_data/entertainer_picture/enfp/man/박준영
# error
# error
# error
# 세븐틴 버논
# /home/nvidia/ai_data/entertainer_picture/enfp/man/세븐틴 버논
# 우주소녀 연정
# /home/nvidia/ai_data/entertainer_picture/entp/woman/우주소녀 연정
# error
# error
# 티아라 큐리
# /home/nvidia/ai_data/entertainer_picture/entp/woman/티아라 큐리
# error
# 드림노트 유아이
# /home/nvidia/ai_data/entertainer_picture/entp/woman/드림노트 유아이
# TXT 태현
# /home/nvidia/ai_data/entertainer_picture/entp/man/TXT 태현
# error
# error
# error
# NCT 재현
# /home/nvidia/ai_data/entertainer_picture/entp/man/NCT 재현
# 비투비 정일훈
# /home/nvidia/ai_data/entertainer_picture/entp/man/비투비 정일훈
# error
# 미스터 T 황윤성
# /home/nvidia/ai_data/entertainer_picture/entp/man/미스터 T 황윤성
# 잔나비 김도형
# /home/nvidia/ai_data/entertainer_picture/entp/man/잔나비 김도형
# error
# error
# error
# error
# (여자)아이들 소연
# /home/nvidia/ai_data/entertainer_picture/intp/woman/(여자)아이들 소연
# error
# error
# 에이핑크 정은지
# /home/nvidia/ai_data/entertainer_picture/intp/woman/에이핑크 정은지
# 오상진
# /home/nvidia/ai_data/entertainer_picture/intp/man/오상진
# error
# error
# 타일러
# /home/nvidia/ai_data/entertainer_picture/intp/man/타일러
# error
# error
# 방탄소년단 진
# /home/nvidia/ai_data/entertainer_picture/intp/man/방탄소년단 진
# error
# 방탄소년단 슈가
# /home/nvidia/ai_data/entertainer_picture/intp/man/방탄소년단 슈가
# error
# 엑소 세훈
# /home/nvidia/ai_data/entertainer_picture/intp/man/엑소 세훈
# error
# 기안84
# /home/nvidia/ai_data/entertainer_picture/intp/man/기안84
# error
# error
# 소녀시대 써니
# /home/nvidia/ai_data/entertainer_picture/lstj/woman/소녀시대 써니
# 홍진경
# /home/nvidia/ai_data/entertainer_picture/lstj/woman/홍진경
# error
# 차태현
# /home/nvidia/ai_data/entertainer_picture/lstj/man/차태현
# 빅스 혁
# /home/nvidia/ai_data/entertainer_picture/lstj/man/빅스 혁
# error
# 인피니트 성규
# /home/nvidia/ai_data/entertainer_picture/lstj/man/인피니트 성규
# error
# iKON 정찬우
# /home/nvidia/ai_data/entertainer_picture/lstj/man/iKON 정찬우
# error
# error
# GOT7 마크
# /home/nvidia/ai_data/entertainer_picture/lstj/man/GOT7 마크
# 업텐션 선율
# /home/nvidia/ai_data/entertainer_picture/lstj/man/업텐션 선율
# error
# error
# 러블리즈 베이비소울
# /home/nvidia/ai_data/entertainer_picture/entj/woman/러블리즈 베이비소울
# error
# 더보이즈 주학년
# /home/nvidia/ai_data/entertainer_picture/entj/woman/더보이즈 주학년
# error
# 소녀시대 티파니
# /home/nvidia/ai_data/entertainer_picture/entj/woman/소녀시대 티파니
# error
# error
# 블락비 지코
# /home/nvidia/ai_data/entertainer_picture/entj/man/블락비 지코
# error
# error
# 스윙스
# /home/nvidia/ai_data/entertainer_picture/entj/man/스윙스
# error
# 샤이니 키
# /home/nvidia/ai_data/entertainer_picture/entj/man/샤이니 키
# error
# error
# error
# 에이스 김병관
# /home/nvidia/ai_data/entertainer_picture/entj/man/에이스 김병관
# error
# 슈퍼주니어 이특
# /home/nvidia/ai_data/entertainer_picture/entj/man/슈퍼주니어 이특
# 트와이스 나연
# /home/nvidia/ai_data/entertainer_picture/istp/woman/트와이스 나연
# error
# error
# error
# error
# error
# 여자친구 은하
# /home/nvidia/ai_data/entertainer_picture/istp/woman/여자친구 은하
# error
# 유빈
# /home/nvidia/ai_data/entertainer_picture/istp/woman/유빈
# error
# 김연아
# /home/nvidia/ai_data/entertainer_picture/istp/woman/김연아
# error
# error
# 장성규
# /home/nvidia/ai_data/entertainer_picture/istp/man/장성규
# 박명수
# /home/nvidia/ai_data/entertainer_picture/istp/man/박명수
# error
# error
# 펜타곤 진호
# /home/nvidia/ai_data/entertainer_picture/istp/man/펜타곤 진호
# error
# 김종민
# /home/nvidia/ai_data/entertainer_picture/istp/man/김종민
# error
# error
# error
# 모모랜드 주이
# /home/nvidia/ai_data/entertainer_picture/esfp/woman/모모랜드 주이
# error
# error
# 카드 전소민
# /home/nvidia/ai_data/entertainer_picture/esfp/woman/카드 전소민
# 소녀시대 수영
# /home/nvidia/ai_data/entertainer_picture/esfp/woman/소녀시대 수영
# error
# error
# sf9 로운
# /home/nvidia/ai_data/entertainer_picture/esfp/man/sf9 로운
# error
# error
# 2PM 우영
# /home/nvidia/ai_data/entertainer_picture/esfp/man/2PM 우영
# error
# error
# 하성운
# /home/nvidia/ai_data/entertainer_picture/esfp/man/하성운
# error
# error
# 비
# /home/nvidia/ai_data/entertainer_picture/esfp/man/비
# error
# error
# error
# CIX 배진영
# /home/nvidia/ai_data/entertainer_picture/esfp/man/CIX 배진영
# error
# 한채영
# /home/nvidia/ai_data/entertainer_picture/estj/woman/한채영
# error
# 모모랜드 제인
# /home/nvidia/ai_data/entertainer_picture/estj/woman/모모랜드 제인
# error
# error
# error
# 이지혜
# /home/nvidia/ai_data/entertainer_picture/estj/woman/이지혜
# error
# error
# error
# GOT7 뱀뱀
# /home/nvidia/ai_data/entertainer_picture/estj/man/GOT7 뱀뱀
# AB6IX 박우진
# /home/nvidia/ai_data/entertainer_picture/estj/man/AB6IX 박우진
# error
# 김민규
# /home/nvidia/ai_data/entertainer_picture/estj/man/김민규
# 데프콘
# /home/nvidia/ai_data/entertainer_picture/estj/man/데프콘
# jyj 김준수
# /home/nvidia/ai_data/entertainer_picture/estj/man/jyj 김준수
# error
# error
# 소녀시대 태연
# /home/nvidia/ai_data/entertainer_picture/infj/woman/소녀시대 태연
# error
# error
# error
# error
# 김새론
# /home/nvidia/ai_data/entertainer_picture/infj/woman/김새론
# error
# 강유미
# /home/nvidia/ai_data/entertainer_picture/infj/woman/강유미
# error
# error
# error
# 마마무 솔라
# /home/nvidia/ai_data/entertainer_picture/infj/woman/마마무 솔라
# error
# 걸스데이 소진
# /home/nvidia/ai_data/entertainer_picture/infj/woman/걸스데이 소진
# 김이나
# /home/nvidia/ai_data/entertainer_picture/infj/woman/김이나
# error
# 위너 강승윤
# /home/nvidia/ai_data/entertainer_picture/infj/man/위너 강승윤
# error
# error
# error
# error
# 엑소 카이
# /home/nvidia/ai_data/entertainer_picture/infj/man/엑소 카이

# %% [markdown]
# # Reference
# 01. How to execute selenium in Ubuntu linux(ENG), https://www.youtube.com/watch?v=67h3IT2lm40
# 02. How to crwaling (KOR), https://www.youtube.com/watch?v=1b7pXC1-IbE&list=PLU9-uwewPMe2-vtJAgWB6SNhHcTjJDgEO&index=2
# 03. search google "python selenium click", https://stackoverflow.com/questions/21350605/python-selenium-click-on-button
